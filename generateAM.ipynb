# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
message_func = input("Enter message signal equation: ")
mod_index = float(input("Enter required modulating index: "))
fc = int(input("Enter carrier frequency: "))

# %%
fs= 40000   # Sampling frequency
T = 1

# %%
twopi= 2*np.pi
t = np.linspace(-T , T, num=fs, endpoint=False)
t
# Out:
# array([-1.     , -0.99995, -0.9999 , ...,  0.99985,  0.9999 ,  0.99995])

# %%
carrier = 3*np.cos(twopi*fc*t)
amplitude_carier = max(carrier)
mp = amplitude_carier*mod_index
message = mp*eval("np."+message_func)
amplitude_carier
# Out:
# 3.0

# %%
plt.subplot(3,1,1)
plt.title("Message Signal")
plt.plot(t,message,'green')
plt.xlabel('Time')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
plt.subplot(3,1,1)
plt.title("Carrier Signal")
plt.plot(t,carrier,'green')
plt.xlabel('Time')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
output = (amplitude_carier + message)*carrier

# %%
plt.subplot(3,1,1)
plt.title("AM Signal")
plt.plot(t,output,'green')
plt.plot(t,0*t,"black")
plt.xlabel('Time')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')
